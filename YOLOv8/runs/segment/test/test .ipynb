# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: torchvision>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (0.15.2)
# ...
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\hp\anaconda3\lib\site-packages)
# ...

# %%
import os
from ultralytics import YOLO

# Verify if the file exists
model_path = r'C:\Users\hp\Desktop\Data\best.pt'  # Make sure this is the correct path to your model
video_path = r'C:\Users\hp\Desktop\Data\road2.mp4.mp4'  # Path to your video file

# List files in the directory for debugging
print("Files in the directory:")
for file in os.listdir(r'C:\Users\hp\Desktop\lane_data'):
    print(file)

# Check if model file exists
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Model file not found: {model_path}")

# Check if video file exists
if not os.path.exists(video_path):
    raise FileNotFoundError(f"Video file not found: {video_path}")

# Load the model
model = YOLO(model_path)

# Run inference on the source
model.predict(video_path, save=True, conf=0.5)
# Out:
# Files in the directory:
# .ipynb_checkpoints
# best.pt
# images
# labels
# mask road.mp4
# masks
# road main.mp4
# road1.mp4.mp4
# road2.mp4.mp4
# road2_resized.mp4
# runs
# test .ipynb
# Untitled.ipynb
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/671) C:\Users\hp\Desktop\Data\road2.mp4.mp4: 640x384 1 road, 2215.7ms
# video 1/1 (frame 2/671) C:\Users\hp\Desktop\Data\road2.mp4.mp4: 640x384 1 road, 366.8ms
# ...

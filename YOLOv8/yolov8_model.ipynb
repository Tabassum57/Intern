# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/Data.zip -d /content/

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
from IPython.display import Image

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.81 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.4/78.2 GB disk)

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-seg.pt')
model.train(data='/content/config.yaml', epochs=65, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.74M/6.74M [00:00<00:00, 183MB/s]
# Ultralytics YOLOv8.2.81 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !zip -r /content/runs.zip /content/Untitled2
# Out:
# 	zip warning: name not matched: /content/Untitled2
#
# zip error: Nothing to do! (try: zip -r /content/runs.zip . -i /content/Untitled2)

# %%
import locale
locale.getpreferredencoding = lambda: 'UTF-8'

# %%
# !export LC_ALL=C.UTF-8
# !export LANG=C.UTF-8

# %%
# validate Yolov8n on coco8 val

# !yolo val model=/content/runs/segment/train/weights/best.pt data=/content/config.yaml
# Out:
# Ultralytics YOLOv8.2.81 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3,258,259 parameters, 0 gradients, 12.0 GFLOPs
# val: Scanning /content/Data/val/labels.cache... 1199 images, 37 backgrounds, 0 corrupt: 100% 1200/1200 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 75/75 [00:30<00:00,  2.46it/s]
#                    all       1200       2162      0.892      0.714      0.806      0.606      0.882      0.705      0.784      0.516
# Speed: 1.2ms preprocess, 5.7ms inference, 0.0ms loss, 3.3ms postprocess per image
# Results saved to runs/segment/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# predict / run inference on an image with Yolov8n

# !yolo predict model=/content/runs/segment/train/weights/best.pt source=/content/Data/val
# Out:
# Ultralytics YOLOv8.2.81 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3,258,259 parameters, 0 gradients, 12.0 GFLOPs
#
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 834, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 565, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/predictor.py", line 183, in predict_cli
#     for _ in gen:  # sourcery skip: remove-empty-nested-block, noqa
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 35, in generator_context
# ...

# %%
# predict / run inference on an image with Yolov8n

# !yolo predict model=/content/runs/segment/train/weights/best.pt source=/content/Data/val/images
# Out:
# Ultralytics YOLOv8.2.81 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3,258,259 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/1200 /content/Data/val/images/120_00000_321.png: 640x640 1 road, 14.4ms
# image 2/1200 /content/Data/val/images/120_00000_322.png: 640x640 1 road, 13.0ms
# image 3/1200 /content/Data/val/images/120_00000_323.png: 640x640 1 road, 10.7ms
# image 4/1200 /content/Data/val/images/120_00000_324.png: 640x640 1 road, 9.4ms
# image 5/1200 /content/Data/val/images/120_00000_325.png: 640x640 1 road, 9.7ms
# image 6/1200 /content/Data/val/images/120_00000_326.png: 640x640 1 road, 9.4ms
# image 7/1200 /content/Data/val/images/120_00000_327.png: 640x640 (no detections), 11.4ms
# image 8/1200 /content/Data/val/images/120_00000_328.png: 640x640 (no detections), 9.3ms
# image 9/1200 /content/Data/val/images/120_00000_329.png: 640x640 3 roads, 9.3ms
# ...

# %%
# !yolo predict model=/content/runs/segment/train/weights/best.pt source=/content/Data/test/images
# Out:
# Ultralytics YOLOv8.2.81 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3,258,259 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/480 /content/Data/test/images/120_00000_291.png: 640x640 4 roads, 9.3ms
# image 2/480 /content/Data/test/images/120_00000_292.png: 640x640 2 roads, 10.0ms
# image 3/480 /content/Data/test/images/120_00000_293.png: 640x640 1 road, 9.3ms
# image 4/480 /content/Data/test/images/120_00000_294.png: 640x640 1 road, 9.3ms
# image 5/480 /content/Data/test/images/120_00000_295.png: 640x640 1 road, 9.3ms
# image 6/480 /content/Data/test/images/120_00000_296.png: 640x640 (no detections), 9.3ms
# image 7/480 /content/Data/test/images/120_00000_297.png: 640x640 1 road, 9.3ms
# image 8/480 /content/Data/test/images/120_00000_298.png: 640x640 1 road, 9.3ms
# image 9/480 /content/Data/test/images/120_00000_299.png: 640x640 1 road, 9.3ms
# ...

# %%
 Image(filename = '/content/runs/segment/train/results.png' , width=600)

# %%
 Image(filename = '/content/runs/segment/train/confusion_matrix_normalized.png' , width=600)

# %%
import os
os.listdir('/content')
# Out:
# ['.config',
#  'yolov8n.pt',
#  'runs',
#  'Data',
#  'drive',
#  'config.yaml',
#  'yolov8n-seg.pt']

# %%
import shutil

# Create a zip file of the 'runs' directory
shutil.make_archive('/content/runs', 'zip', '/content/runs')
# Out:
# '/content/runs.zip'

# %%
from google.colab import files

# Download the newly created zip file
files.download('/content/runs.zip')

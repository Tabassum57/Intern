# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/cityscapes.zip -d /content/

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.8 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.81 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.5/107.7 GB disk)

# %%
from ultralytics import YOLO

# %%
from IPython.display import Image

# %%
# validate Yolov8n on coco8 val

# !yolo val model=/content/best.pt data=/content/config.yaml
# Out:
# Ultralytics YOLOv8.2.81 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-seg summary (fused): 195 layers, 3,258,259 parameters, 0 gradients, 12.0 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 20.7MB/s]
# val: Scanning /content/cityscapes/val/labels... 156 images, 0 backgrounds, 0 corrupt: 100% 156/156 [00:02<00:00, 75.36it/s]
# val: New cache created: /content/cityscapes/val/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 10/10 [00:53<00:00,  5.33s/it]
#                    all        156        163      0.803      0.777      0.797      0.142     0.0109     0.0123   0.000646   6.46e-05
# Speed: 2.0ms preprocess, 218.0ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/segment/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# predict / run inference on an image with Yolov8n

# !yolo predict model=/content/best.pt source=/content/cityscapes/val/images
# Out:
# Ultralytics YOLOv8.2.81 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-seg summary (fused): 195 layers, 3,258,259 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/156 /content/cityscapes/val/images/frankfurt_000000_000294.png: 320x640 1 road, 174.3ms
# image 2/156 /content/cityscapes/val/images/frankfurt_000000_000576.png: 320x640 (no detections), 161.1ms
# image 3/156 /content/cityscapes/val/images/frankfurt_000000_001016.png: 320x640 2 roads, 143.6ms
# image 4/156 /content/cityscapes/val/images/frankfurt_000000_001236.png: 320x640 1 road, 148.3ms
# image 5/156 /content/cityscapes/val/images/frankfurt_000000_001751.png: 320x640 1 road, 135.8ms
# image 6/156 /content/cityscapes/val/images/frankfurt_000000_002196.png: 320x640 1 road, 142.6ms
# image 7/156 /content/cityscapes/val/images/frankfurt_000000_002963.png: 320x640 1 road, 156.3ms
# image 8/156 /content/cityscapes/val/images/frankfurt_000000_003025.png: 320x640 1 road, 144.2ms
# ...

# %%
  Image(filename = '/content/runs/segment/val/confusion_matrix_normalized.png' , width=600)

# %%
  Image(filename = '/content/runs/segment/val/BoxF1_curve.png' , width=600)

# %%
Image(filename = '/content/runs/segment/val/BoxP_curve.png' , width=600)

# %%
Image(filename = '/content/runs/segment/val/BoxR_curve.png' , width=600)

# %%
Image(filename = '/content/runs/segment/val/BoxPR_curve.png' , width=600)

# %%
import shutil

# Create a zip file of the 'runs' directory
shutil.make_archive('/content/runs', 'zip', '/content/runs')
# Out:
# '/content/runs.zip'

# %%
from google.colab import files

# Download the newly created zip file
files.download('/content/runs.zip')
